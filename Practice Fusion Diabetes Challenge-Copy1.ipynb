# %%
# %%bash
# # These files appear to be from the original competition (that is unmodified)
# wget -q -c https://raw.githubusercontent.com/yasminlucero/Kaggle/master/Data/compDataAsSQLiteDB/compData.db
# wget -q -c https://raw.githubusercontent.com/yasminlucero/Kaggle/master/Data/compDataAsSQLiteDB/compData.sql

# %%
# %matplotlib inline

import sqlite3
import pandas as pd
from contextlib import closing
import numpy as np
import seaborn as sns

with closing(sqlite3.connect('file:compData.db?mode=ro', uri=True)) as conn:    
    patientTranscripts = pd.read_sql_query("""
SELECT PatientGuid,
    dmIndicator,
    Gender,
    YearOfBirth,
    VisitYear,
    CASE WHEN BMI = 0 THEN NULL ELSE BMI END AS BMI,
    CASE WHEN SystolicBP = "NULL" THEN NULL ELSE SystolicBP END AS SystolicBP,
    CASE WHEN DiastolicBP = "NULL" THEN NULL ELSE DiastolicBP END AS DiastolicBP,
    CASE WHEN RespiratoryRate = "NULL" THEN NULL ELSE RespiratoryRate END AS RespiratoryRate
FROM training_patientTranscript
""", conn)

patientTranscripts = patientTranscripts.sort_values(['VisitYear'],  ascending=False)
patientTranscripts.groupby('PatientGuid', as_index=False).agg(lambda x: x.loc[x.first_valid_index()])

patientTranscripts.dropna(axis=1, how='any')
# Out:
#                                  PatientGuid  dmIndicator Gender  YearOfBirth  \
# 118234  8093EC9B-9AF2-4B70-BD3D-E5ECE1D3CAD1            0      M         1935
# 47005   D1AEE480-5BDF-4983-A603-591DA6279972            1      M         1963
# 111271  32B2359C-FCFE-4AD5-A0C3-D9219D53F599            1      M         1946
# 99526   06BD76A2-370A-4D1D-83C6-C0AF43851D26            0      F         1981
# 14359   A4F71429-74B4-4B65-BF13-1DB401F29A3B            0      F         1951
# 111265  006E3A23-F786-4ED2-BE70-D91D23BA56EA            1      M         1939
# 63155   B8275AEC-E8B5-4FB3-B35E-7745C228F747            0      F         1969
# 29502   47F49930-C0BE-4318-A999-39F2B374A379            1      F         1938
# 63159   E0ED49EF-5DD3-49BD-AC48-774CCEE5AA90            0      F         1946
# 121329  22A31B9F-6688-452C-82F8-EC02A318AF71            1      F         1935
# 63163   E0ED49EF-5DD3-49BD-AC48-774CCEE5AA90            0      F         1946
# 121334  22A31B9F-6688-452C-82F8-EC02A318AF71            1      F         1935
# 63166   E0ED49EF-5DD3-49BD-AC48-774CCEE5AA90            0      F         1946
# 63169   E0ED49EF-5DD3-49BD-AC48-774CCEE5AA90            0      F         1946
# 63171   3BBFB6DB-CDF6-485A-B1AF-774DEAD8DF75            1      F         1933
# 63173   3BBFB6DB-CDF6-485A-B1AF-774DEAD8DF75            1      F         1933
# 99557   D1182AF2-9883-4463-8352-C0BC1E0C8016            1      M         1938
# 63143   6E55D72A-A2CB-41F0-A8C3-773376BC0FAA            0      F         1973
# 88419   6B15CD94-99DA-44C9-9C16-A9FC36F17989            0      F         1992
# 121318  22A31B9F-6688-452C-82F8-EC02A318AF71            1      F         1935
# 88426   6B15CD94-99DA-44C9-9C16-A9FC36F17989            0      F         1992
# 29480   E89813EB-36AA-48D4-994E-39E9C81888D6            0      M         1960
# 47054   67DAE97B-1562-4F58-8512-5947D0322853            0      M         1956
# 88428   6B15CD94-99DA-44C9-9C16-A9FC36F17989            0      F         1992
# 121300  F2D2B17B-93B9-4984-B5EC-EBFF74F57B86            0      M         1962
# 63127   6E55D72A-A2CB-41F0-A8C3-773376BC0FAA            0      F         1973
# 88427   6B15CD94-99DA-44C9-9C16-A9FC36F17989            0      F         1992
# 121308  22A31B9F-6688-452C-82F8-EC02A318AF71            1      F         1935
# 88423   6B15CD94-99DA-44C9-9C16-A9FC36F17989            0      F         1992
# 88425   6B15CD94-99DA-44C9-9C16-A9FC36F17989            0      F         1992
# ...                                      ...          ...    ...          ...
# 38790   7A7A1073-8E53-43D2-AC78-4ACCD9448B24            0      F         1985
# 61971   25D3FD87-5835-45C7-9786-753609F9C9B3            0      F         1953
# 61970   25D3FD87-5835-45C7-9786-753609F9C9B3            0      F         1953
# 38791   7A7A1073-8E53-43D2-AC78-4ACCD9448B24            0      F         1985
# 61967   25D3FD87-5835-45C7-9786-753609F9C9B3            0      F         1953
# 61965   25D3FD87-5835-45C7-9786-753609F9C9B3            0      F         1953
# 61951   25D3FD87-5835-45C7-9786-753609F9C9B3            0      F         1953
# 61948   25D3FD87-5835-45C7-9786-753609F9C9B3            0      F         1953
# 105183  B9806186-11E4-4453-904B-CD0CAF07A774            0      F         1984
# 105187  B9806186-11E4-4453-904B-CD0CAF07A774            0      F         1984
# 105190  B9806186-11E4-4453-904B-CD0CAF07A774            0      F         1984
# 105198  B9806186-11E4-4453-904B-CD0CAF07A774            0      F         1984
# 7167    498421C5-3895-47FC-9312-0EF9B85ED820            1      F         1927
# 7168    498421C5-3895-47FC-9312-0EF9B85ED820            1      F         1927
# 7173    498421C5-3895-47FC-9312-0EF9B85ED820            1      F         1927
# 105278  C6FBA8BC-E5C8-4EF5-B1FA-CD3C34326848            1      F         1933
# 105277  C6FBA8BC-E5C8-4EF5-B1FA-CD3C34326848            1      F         1933
# 7177    498421C5-3895-47FC-9312-0EF9B85ED820            1      F         1927
# 7178    498421C5-3895-47FC-9312-0EF9B85ED820            1      F         1927
# 7180    498421C5-3895-47FC-9312-0EF9B85ED820            1      F         1927
# 7183    498421C5-3895-47FC-9312-0EF9B85ED820            1      F         1927
# 7185    498421C5-3895-47FC-9312-0EF9B85ED820            1      F         1927
# 7188    E5A05D7F-CDDD-48FD-9276-0EFA8F831EEB            1      M         1982
# 7190    E5A05D7F-CDDD-48FD-9276-0EFA8F831EEB            1      M         1982
# 117804  95F944BA-5A65-4DF0-8F75-E521BE014337            0      M         1973
# 7197    E5A05D7F-CDDD-48FD-9276-0EFA8F831EEB            1      M         1982
# 38672   DB3850CD-0FED-4E6D-8954-4A76E54C8743            0      F         1966
# 38674   DB3850CD-0FED-4E6D-8954-4A76E54C8743            0      F         1966
# 38687   DB3850CD-0FED-4E6D-8954-4A76E54C8743            0      F         1966
# 126169  F972411F-70CD-4486-B477-F609EE2C5E99            0      F         1971
#
#         VisitYear
# 118234       2012
# 47005        2012
# 111271       2012
# 99526        2012
# 14359        2012
# 111265       2012
# 63155        2012
# 29502        2012
# 63159        2012
# 121329       2012
# 63163        2012
# 121334       2012
# 63166        2012
# 63169        2012
# 63171        2012
# 63173        2012
# 99557        2012
# 63143        2012
# 88419        2012
# 121318       2012
# 88426        2012
# 29480        2012
# 47054        2012
# 88428        2012
# 121300       2012
# 63127        2012
# 88427        2012
# 121308       2012
# 88423        2012
# 88425        2012
# ...           ...
# 38790           0
# 61971           0
# 61970           0
# 38791           0
# 61967           0
# 61965           0
# 61951           0
# 61948           0
# 105183          0
# 105187          0
# 105190          0
# 105198          0
# 7167            0
# 7168            0
# 7173            0
# 105278          0
# 105277          0
# 7177            0
# 7178            0
# 7180            0
# 7183            0
# 7185            0
# 7188            0
# 7190            0
# 117804          0
# 7197            0
# 38672           0
# 38674           0
# 38687           0
# 126169          0
#
# [131031 rows x 5 columns]

# %%
#patientTranscripts.loc[patientTranscripts.Weight.isnull(), 'Weight'] = patientTranscripts.groupby('PatientGuid').Weight.transform('mean')
#patientTranscripts["Weight"] = patientTranscripts.groupby("PatientGuid").Weight.transform(lambda x: x.fillna(x.mean()))
#patientTranscripts
#patientTranscripts.sort_values(['VisitYear'], ascending=False).groupby(['PatientGuid']).head(1)

# %%
#patientTranscripts = patientTranscripts.sort_values(['VisitYear'],  ascending=False)
#patientTranscripts.groupby('PatientGuid', as_index=False).agg(lambda x: x.loc[x.first_valid_index()])

#patientTranscripts["Height"] = patientTranscripts.groupby("PatientGuid").Height.transform(lambda x: x.fillna(s.loc[s.first_valid_index()))
#patientTranscripts.groupby("PatientGuid").Height.transform(lambda x: x.fillna(x.loc[x.first_valid_index()]))
#patientTranscripts

#patientTranscripts.apply(lambda x:x.fillna(x.value_counts().index[0]))
#a if condition else b
#g = patientTranscripts.groupby(["PatientGuid"]).transform(lambda x: np.nan if x.first_valid_index() is None else x.fillna(x.loc[x.first_valid_index()]))
#g = patientTranscripts.groupby("PatientGuid", as_index=False).transform(lambda x: x.fillna(x.loc[x.first_valid_index()]))

#g.groupby(["PatientGuid"]).first().reset_index()
#patientTranscripts.groupby("PatientGuid").transform(lambda x: x.fillna(method='ffill'))
#g.dropna(axis=0, how='any')
#df.fillna(method='ffill')

#  Is there a way to do this to all NAs?
#patientTranscripts.groupby("PatientGuid").BMI.transform(lambda x: x.fillna(x.loc[x.first_valid_index()]))
                                                                                                                   #g = patientTranscripts.sort_values(['VisitYear'], ascending=False).groupby(['PatientGuid'])
#g['Weight'].transform(lambda s: s.loc[s.first_valid_index()])
# Out:
#                                PatientGuid  dmIndicator Gender  YearOfBirth  \
# 0     00023761-9D8D-445B-874C-2424CC7CF620            0      M         1956
# 1     0005D9BD-0247-4F02-B7EE-7C1B44825FA1            0      F         1952
# 2     000B4862-7CE7-4EC5-8043-A97FCD74BD78            0      F         1925
# 3     00110ABC-DAB9-49E3-A1C8-88BBF8D58109            0      M         1970
# 4     002667F4-B9A3-4DE2-875F-8034DD637865            0      F         1928
# 5     0029BBC8-7C22-4444-9F44-87BEF05FE033            0      F         1953
# 6     003CEE1F-5BF5-4171-9284-F5464EC12D41            0      F         1926
# 7     004382BD-E31F-4091-8DE5-E86A59D70C2D            0      F         1961
# 8     004AACFF-5D67-49B3-81F4-883A72A2AB97            0      F         1985
# 9     004CC712-BAD3-4A0E-8C9D-659F6C83A3AD            0      M         1987
# 10    004EA6A7-6159-4D70-B06A-C0391D8623BD            0      F         1984
# 11    005F61C9-E537-4AD2-B39C-37F25891F33A            0      F         1931
# 12    00607D4B-5F8F-4026-AF20-85A961B4B904            0      F         1973
# 13    0063B34F-C2C4-423A-A144-E51F7149253A            0      F         1968
# 14    0066553F-732C-4654-99AA-68B26819DFD8            0      F         1945
# 15    006948F2-1118-4F56-A561-6A254EE357C6            0      M         1966
# 16    006A9198-1BB4-42B9-A864-210BF14AD445            0      F         1970
# 17    006BF25A-315A-479D-9E3E-B9E98015164D            0      F         1979
# 18    006E3A23-F786-4ED2-BE70-D91D23BA56EA            1      M         1939
# 19    006F8D62-651E-4ADD-B630-8F7DB667C148            0      M         1933
# 20    0070A69E-281C-45F4-8D91-82E541D3174C            0      F         1977
# 21    0073C602-D9AE-480D-83AD-5A2B95CDA78E            0      F         1985
# 22    007CB9B1-F4DE-44FA-9CEC-916C1235988C            0      M         1948
# 23    008383B8-BF24-4DBB-A848-A377A4899599            0      M         1972
# 24    008A55FD-0735-47EC-A2FA-20043D1423C2            0      F         1963
# 25    008BEF94-97B7-46B8-AFD8-01964AA5F067            0      F         1986
# 26    00929C2B-FCED-4386-935A-879A8FA97B08            0      F         1967
# 27    0094395F-F853-4689-85D3-4AE5C2EA3EC0            0      F         1953
# 28    009E23BA-BE03-4367-AB97-94DC981115CA            0      F         1948
# 29    009FFF75-B641-4EFD-87EB-53BAC29906F5            0      F         1949
# ...                                    ...          ...    ...          ...
# 9918  FF5211D7-DCED-4533-BE00-85780DA0151B            0      M         1955
# 9919  FF53A018-F809-4B99-A451-972FB3360010            1      M         1950
# 9920  FF574B32-F375-411E-B7C4-99C6034A187A            0      F         1939
# 9921  FF58FBFA-320E-4970-B93F-1D36F81F4FFD            0      M         1963
# 9922  FF5DB6F4-3008-45DC-BA65-21675EE0DFB2            1      M         1971
# 9923  FF601D92-E2AE-4042-A247-B09614E1C203            0      M         1961
# 9924  FF618A7A-92FE-4651-8646-D43E81E7A949            0      F         1941
# 9925  FF64E901-267B-4095-B9D7-880BEA72B44B            0      F         1973
# 9926  FF69D56A-B1C5-4F04-B458-5F58BB9E70E6            0      F         1973
# 9927  FF71CFBD-D0FB-4754-A84C-07A367832C8F            0      M         1980
# 9928  FF8011CC-ABB1-4E70-8F25-FEB75F33396F            0      F         1956
# 9929  FF827F18-B26E-4B6A-B03D-1BE5F6768B88            0      M         1951
# 9930  FF99C22E-E5B5-442A-B0B0-73747BD2F04E            0      M         1963
# 9931  FF9B4F39-5A81-4150-9E2C-550BDE418FFB            0      F         1965
# 9932  FF9BA1EB-03AB-47FE-B110-B559D8E0835B            0      F         1925
# 9933  FFA25126-98E0-46E2-9B80-FBEEEA1C7D71            0      F         1948
# 9934  FFA4B4D2-BBC8-440F-9672-534E9C017F69            1      M         1975
# 9935  FFAF77EC-1129-4CAB-B55F-6AC63E9227F4            1      M         1937
# 9936  FFB0830F-B789-4B37-A43C-6E2A02368F5E            0      M         1993
# 9937  FFB3BB66-F74A-462E-A9B8-F982857B4CB3            1      M         1947
# 9938  FFB51256-FBE9-4825-9172-09789E757770            0      M         1937
# 9939  FFB6EAD7-1BFB-4EDD-BC30-67CD1E214474            0      M         1979
# 9940  FFC5A6AA-1344-4D50-B128-591534D77049            0      F         1970
# 9941  FFC8E19F-A199-46A3-895A-E3C07FBAC809            0      M         1940
# 9942  FFC9E47E-6971-4210-8370-3FB01BB1B47F            0      F         1942
# 9943  FFCCEB55-7FCA-4CCD-A035-9672674F2353            0      M         1983
# 9944  FFCD70A8-72FC-4F06-AC19-D9962B2CA95E            0      F         1984
# 9945  FFEF293B-6147-47F0-8F0B-76180C124205            0      F         1965
# 9946  FFF2B406-9C3F-4A8B-8B27-7179B7D7FBC6            1      M         1930
# 9947  FFF5C634-1CF7-40D5-BDF1-4FA2D62D9C63            0      F         1947
#
#       VisitYear     BMI
# 0          2009  27.670
# 1          2010   0.000
# 2          2012   0.000
# 3          2012   0.000
# 4          2010  19.388
# 5          2012   0.000
# 6          2012  20.026
# 7          2011  42.864
# 8          2011   0.000
# 9          2011  24.226
# 10         2010  22.238
# 11         2012   0.000
# 12         2012   0.000
# 13         2012  45.415
# 14         2010   0.000
# 15         2012  27.436
# 16         2012  18.630
# 17         2012   0.000
# 18         2012  31.831
# 19         2012   0.000
# 20         2011  36.416
# 21         2011   0.000
# 22         2010  25.766
# 23         2012   0.000
# 24         2011  33.200
# 25         2010   0.000
# 26         2012   0.000
# 27         2011  19.568
# 28         2012   0.000
# 29         2010  24.622
# ...         ...     ...
# 9918       2011  35.143
# 9919       2010  37.704
# 9920       2012  23.794
# 9921       2012   0.000
# 9922       2011  39.024
# 9923       2012  34.199
# 9924       2011  17.472
# 9925       2011  18.852
# 9926       2010   0.000
# 9927       2010  27.406
# 9928       2010  23.203
# 9929       2012  24.482
# 9930       2012  27.435
# 9931       2010   0.000
# 9932       2011  21.146
# 9933       2011   0.000
# 9934       2012  23.330
# 9935       2011  36.184
# 9936       2012   0.000
# 9937       2012  25.804
# 9938       2012   0.000
# 9939       2012  28.577
# 9940       2011  25.745
# 9941       2012  29.427
# 9942       2011   0.000
# 9943       2012  25.857
# 9944       2012  25.860
# 9945       2012  37.454
# 9946       2012   0.000
# 9947       2012   0.000
#
# [9948 rows x 6 columns]
